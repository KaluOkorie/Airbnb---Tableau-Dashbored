# %%
from pathlib import Path

# Project root (current working directory)
project_dir = Path.cwd()

# Define folders
NOTEBOOK_DIR = project_dir / "notebooks"
INPUT_DIR = project_dir / "Inputs"
OUTPUT_DIR = project_dir / "outputs"

# Create folders if they don't exist
for folder in [NOTEBOOK_DIR, INPUT_DIR, OUTPUT_DIR]:
    folder.mkdir(parents=True, exist_ok=True)

# Print paths
print("Project Directory:", project_dir)
print("Notebook Directory:", NOTEBOOK_DIR)
print("Input Directory:", INPUT_DIR)
print("Output Directory:", OUTPUT_DIR)
# Out:
# Project Directory: /Users/2020m1/Downloads/Github-Repos/Airbnb - Tableau Dashbored
# Notebook Directory: /Users/2020m1/Downloads/Github-Repos/Airbnb - Tableau Dashbored/notebooks
# Input Directory: /Users/2020m1/Downloads/Github-Repos/Airbnb - Tableau Dashbored/Inputs
# Output Directory: /Users/2020m1/Downloads/Github-Repos/Airbnb - Tableau Dashbored/outputs
